# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_close_prices = pd.read_csv('./close_prices.csv')
data_close_prices = data_close_prices.drop('date', axis = 1)
data_close_prices.head()
# Out:
#          AXP          BA        CAT       CSCO         CVX         DD  \
# 0  76.440002  117.510002  85.029999  24.270000  125.519997  59.409999
# 1  76.070000  119.000000  85.110001  24.139999  124.489998  59.319997
# 2  75.989998  118.510002  84.500000  24.430000  124.070000  59.319997
# 3  76.320000  119.379997  84.199997  23.770000  123.489998  59.509996
# 4  75.889999  118.739998  83.800003  23.330000  122.639999  59.009995
#
#          DIS         GE          GS         HD    ...            PFE  \
# 0  64.750000  24.280001  165.250000  75.910004    ...      28.799999
# 1  64.320000  24.320000  162.970001  76.040001    ...      28.709999
# 2  64.449997  24.230000  162.309998  75.519997    ...      28.490000
# 3  65.239998  24.250000  162.289993  76.070000    ...      28.520000
# 4  65.190002  24.049999  159.850006  75.959999    ...      28.879999
#
#           PG          T        TRV        UNH         UTX           V  \
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 10)
pca.fit(data_close_prices)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
[pca.explained_variance_ratio_[:i].sum() for i in range(len(pca.explained_variance_))]
# Out:
# [0.0,
#  0.73897118271521545,
#  0.84904287281391777,
#  0.89899375558370787,
#  0.92774295378364036,
#  0.94989743266327931,
#  0.96921319917371207,
#  0.97596173073696968,
#  0.9821026409235678,
#  0.98530858260924548]

# %%
X = pca.transform(data_close_prices)
X = [i[0] for i in X]
X
# Out:
# [-50.902403581010702,
#  -52.846909188826068,
#  -54.614439170742905,
#  -52.600566275002208,
#  -52.370123300508446,
#  -54.653411971736247,
#  -52.812574961425987,
#  -53.651145700604928,
#  -56.692726979900584,
#  -54.402655055053053,
#  -58.331645486603719,
#  -61.71626498230254,
#  -61.319400254401863,
#  -53.792524454161025,
#  -50.892634483259741,
#  -49.63740755273961,
#  -52.387614697901846,
#  -47.478542944492055,
#  -43.560334987105783,
#  -42.559280462451298,
#  -42.450270865743583,
#  -42.271247971899371,
#  -43.252728161485884,
#  -40.059344814645371,
#  -38.497263152457627,
#  -39.06492262604911,
#  -38.393043775493837,
#  -38.400558325177684,
#  -42.386169809191784,
#  -39.830574170990602,
#  -41.295486040989154,
#  -40.435549577618382,
#  -38.496079322442817,
#  -42.961580524161334,
#  -38.712521434784335,
#  -38.833793314344682,
#  -39.906061738562826,
#  -37.588245223326631,
#  -34.923567252430566,
#  -32.962326936118146,
#  -34.524617221835307,
# ...

# %%
data_djia = pd.read_csv('./djia_index.csv')
data_djia.head()
# Out:
#          date          ^DJI
# 0  2013-09-23  15401.379883
# 1  2013-09-24  15334.589844
# 2  2013-09-25  15273.259766
# 3  2013-09-26  15328.299805
# 4  2013-09-27  15258.240234

# %%
np.corrcoef(X, data_djia['^DJI'])
# Out:
# array([[ 1.        ,  0.90965222],
#        [ 0.90965222,  1.        ]])

# %%
np.argmax(list(map(abs, pca.components_[0])))
# Out:
# 26

# %%
data_close_prices.columns[26]
# Out:
# 'V'
